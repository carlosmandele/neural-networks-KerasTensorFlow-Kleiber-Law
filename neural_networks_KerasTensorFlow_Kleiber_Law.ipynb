# %% [markdown]
# ### <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
#
# #### <div class="license">
# <span>License CC BY-NC-SA</span>
# <span>Carlos Mandele</span>
# </div>

# %% [markdown]
# # <h1 style="font-size:250%;text-align:center">Deep Learning:</h1>
# ## <h1 style="font-size:250%;text-align:center">Aproximando uma lei da natureza diretamente dos dados com redes neurais</h1>
# <h4 style="font-size:150%;text-align:center">by Carlos Mandele</h4>
# <h5 style="font-size:100%;text-align:center">Data Scientist, in progress</h5>

# %% [markdown]
# Aproximando uma lei da natureza diretamente dos dados com Deep Learning

# %% [markdown]
# A <a href="https://en.wikipedia.org/wiki/Kleiber%27s_law" target="_blank">lei de Kleiber </a>, formulada pelo biólogo Max Kleiber na década de 1930, afirma que o consumo de energia (metabolismo) dos seres vivos, varia segundo a potência de 3/4 de sua massa corporal. Esta lei funciona de bactérias a baleias, no entanto permanece por enquanto sem explicação física ou geométrica satisfatória. O objetivo deste projeto é prever o metabolismo a partir da massa corporal de uma determinada espécie de seres vivos, usando redes neurais (arquitetura de redes neurais MLP) com o framework Keras/TensorFlow.

# %% [markdown]
# ### Importação das bibliotecas

# %%
# Importando bibliotecas Python
import tensorflow as tf
import numpy as np
import pandas as pd
print("Bibliotecas python importadas")
# Out:
# Bibliotecas python importadas

# %% [markdown]
# ## Definindo possibilidades de reprodutibilidade
#
# O desenvolvimento de redes neurais envolve certos processos aleatórios.
# Durante os ensaios, é estabelecido temporariamente o estado aleatório para reprodutibilidade, em seguida reitera-se o experimento com diferentes amostragens ou estados aleatórios e obtém-se a média dos resultados.
#
#
#
# **NOTA**: para um sistema em produção, você simplesmente revive o estado puramente aleatório com a instrução 'GERME_ALEATÓRIO = "None"

# %%
import os

# Definindo um germe aleatório
GERME_ALEATORIO = 1

# Determinar um estado aleatório para Python
os.environ['PYTHONHASHSEED'] = str(GERME_ALEATORIO)

# Determinar um estado aleatório para Python random
import random
random.seed(GERME_ALEATORIO)

# Determinar um estado aleatório para NumPy
import numpy as np
np.random.seed(GERME_ALEATORIO)

# Definindo um estado aleatório para TensorFlow
import tensorflow as tf
tf.random.set_seed(GERME_ALEATORIO)

os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

print("Germe aleatório fixo")
# Out:
# Germe aleatório fixo

# %% [markdown]
# # Aquisição de dados....
#
# #### **Fonte**: http://sites.science.oregonstate.edu/~schaferd/Sleuth/data-sets.html
#
# Ramsey, F., & Schafer, D. (2012). The statistical sleuth: a course in methods of data analysis. Cengage Learning.

# %% [markdown]
# ## Carregamento da base de dados

# %%
# Criando um diretório para os dados
! mkdir KleiberLaw

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Leitura da base de dados

# %%
# Leitura dos dados
dados_kleiber = pd.read_csv("/content/drive/MyDrive/ColabPPortfoio/KleiberLaw.csv")
print("Leitura dos dados concluida")
# Out:
# Leitura dos dados concluida

# %% [markdown]
# ## Visualizando os dados

# %%
# Exibindo informações básicas sobre o conjunto de dados
dados_kleiber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  95 non-null     int64
#  1   CommonName  95 non-null     object
#  2   Species     95 non-null     object
#  3   Mass        95 non-null     float64
#  4   Metabolism  95 non-null     float64
#  5   Lifespan    95 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 4.6+ KB

# %% [markdown]
# O conjunto de dados tem 95 registros e 5 atributos: 'CommonName', 'Species', 'Mass', 'Metabolism', 'Lifespan'

# %%
#Exibindo as n primeiras linhas do conjunto de dados
dados_kleiber.head()
# Out:
#    Unnamed: 0              CommonName                   Species    Mass  \
# 0           0                 Echidna    Tachiglossus aculeatus   2.500
# 1           1     Long-beaked echidna         Zaglossus bruijni  10.300
# 2           2                Platypus  Ornithorhynchus anatinus   1.300
# 3           3                 Opossum  Lutreolina crassicaudata   0.812
# 4           4  South American opossum     Didelphis marsupialis   1.330
#
#    Metabolism  Lifespan
# 0       302.0      14.0
# 1       594.0      20.0
# 2       229.0       9.0
# 3       196.0       5.0
# 4       299.0       6.0

# %%
# Exibindo uma amostra selecionada aleatoriamente de 5 cópias do conjunto de dados
dados_kleiber.sample(n=5,random_state=42)

# mass em kg
# métabolism em kJ
# Out:
#     Unnamed: 0      CommonName                 Species   Mass  Metabolism  \
# 68          68         Chamois     Rupicapra rupicapra  40.00      3140.0
# 22          22  Scaly anteater          Manis javanica   4.22       529.0
# 72          72       Wolverine                Gulogulo  12.70      2820.0
# 73          73          Badger             Meles meles  11.10      1440.0
# 0            0         Echidna  Tachiglossus aculeatus   2.50       302.0
#
#     Lifespan
# 68      21.0
# 22      11.0
# 72      15.0
# 73      16.0
# 0       14.0

# %% [markdown]
# ## Pré-processamento de dados

# %%
# Cria-se um novo DF, deletando as colunas desnecessárias
df_new= dados_kleiber.drop(columns='Unnamed: 0')
df_new
# Out:
#                 CommonName                   Species     Mass  Metabolism  \
# 0                  Echidna    Tachiglossus aculeatus    2.500       302.0
# 1      Long-beaked echidna         Zaglossus bruijni   10.300       594.0
# 2                 Platypus  Ornithorhynchus anatinus    1.300       229.0
# 3                  Opossum  Lutreolina crassicaudata    0.812       196.0
# 4   South American opossum     Didelphis marsupialis    1.330       299.0
# ..                     ...                       ...      ...         ...
# 90           Rhesus monkey            Macaca mulatta    5.000       960.0
# 91               Orangutan           Pongo pygma eus  150.000     15500.0
# 92                 Gorilla           Gorilla gorilla  250.000     21000.0
# 93                  Gibbon             Hylobater lar    8.000      1510.0
# 94                   # Man              Homo sapiens   65.000      7560.0
#
#     Lifespan
# 0       14.0
# 1       20.0
# 2        9.0
# 3        5.0
# 4        6.0
# ..       ...
# 90      25.0
# 91      45.0
# 92      45.0
# 93      25.0
# 94      75.0
#
# [95 rows x 5 columns]

# %% [markdown]
# ### Seleção
# Extração de atributos que serão usados para previsão ou variáveis independentes.
#
# **Nota**: o objetivo é tentar prever o metabolismo a partir da massa, portanto, apenas um atributo preditivo, a massa.

# %%
from sklearn.preprocessing import StandardScaler

# Extração de atributos que serão usados para previsão ou variáveis independentes
atributo_preditiv = df_new["Mass"].values.reshape(-1, 1)

# Normalisação do atributo preditivo para facilitar o trabalho do algoritmo
normalizador_atributo_preditiv = StandardScaler()
normalizador_atributo_preditiv.fit(atributo_preditiv)
atributo_preditiv = normalizador_atributo_preditiv.transform(atributo_preditiv)
print("Atributo preditivo extraído e normalizado")
# Out:
# Atributo preditivo extraído e normalizado

# %% [markdown]
# Extração do atributo que se procura prever ou atributo alvo ou variável dependente.
#
# Nota: o bjetivo é tentar prever o metabolismo e, portanto, apenas um atributo-alvo, o metabolismo.

# %%
# Extração do atributo a ser previsto ou atributo alvo ou variável dependente
atributo_target = df_new['Metabolism'].values.reshape(-1, 1)

# Normalisação do atributo alvo para facilitar o trabalho do algoritmo
normalizador_atributo_target = StandardScaler()
normalizador_atributo_target.fit(atributo_target)
atributo_target = normalizador_atributo_target.transform(atributo_target)
print("Atributo alvo extraído e normalizado")
# Out:
# Atributo alvo extraído e normalizado

# %% [markdown]
# ## Construção de uma rede neural tipo MLP (Multilayer Perceptron) com três camadas:
# - ### camada de entrada, camada oculta, camada de saída

# %%
#Construção de uma rede neural tipo percptron de três camadas:
#camada de entrada, camada oculta, camada de saída
modelo_rede_neural = tf.keras.models.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1]),
                                                 tf.keras.layers.Dense(units=10, activation='relu'),
                                                 tf.keras.layers.Dense(units=1)])
# Visualizando a arquitetura da rede
print("Arquitetura de redes neurais:")
modelo_rede_neural.summary()
# Out:
# Arquitetura de redes neurais:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
#  dense_1 (Dense)             (None, 10)                20
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compilação da rede neural
# - ### otimizador: Adam
# - ### taxa de aprendizagem: 0,001
# - ### função de erro: erro quadrado médio ('mean_squared_error')

# %%
# Compilação da rede neural - Otimizador: Adam, Taxa de aprendizagem: 0,001,
# Função de erro: Erro quadratico médio (mean_squared_error)
modelo_rede_neural.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                           loss='mean_squared_error')

print("Rede de neurónios compilada")
# Out:
# Rede de neurónios compilada

# %% [markdown]
# ## Treinando a rede neural em dados:
# - ### atributo_preditiv e atributo_target
# - ### para 500 iterações ou épocas
#
#
# **NOTA**: uma época representa a exposição de toda a base de dados de treiamento para a rede (modelo).

# %%
# Treinando a rede neural em dados: Variável predetiva(mass) e variável alvo(metabolism),
# para 500 iterações ou épocas
trail = modelo_rede_neural.fit(atributo_preditiv,atributo_target,epochs=500,verbose=1)
# Exibição de erros no final do treinamento
print("Erro no final:",trail.history['loss'][-1])
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 8ms/step - loss: 1.3312
# Epoch 2/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3194
# Epoch 3/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3131
# Epoch 4/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2971
# Epoch 5/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2887
# Epoch 6/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2751
# Epoch 7/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2689
# Epoch 8/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2560
# Epoch 9/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2460
# Epoch 10/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2343
# Epoch 11/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2252
# Epoch 12/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2183
# Epoch 13/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2066
# Epoch 14/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1981
# Epoch 15/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1933
# Epoch 16/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1808
# Epoch 17/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1741
# Epoch 18/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1662
# Epoch 19/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1596
# Epoch 20/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1481
# Epoch 21/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1441
# Epoch 22/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1347
# Epoch 23/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1257
# Epoch 24/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1221
# Epoch 25/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1147
# Epoch 26/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1045
# Epoch 27/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0998
# Epoch 28/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0918
# Epoch 29/500
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0885
# Epoch 30/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0812
# Epoch 31/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0750
# Epoch 32/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0660
# Epoch 33/500
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0599
# Epoch 34/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0542
# Epoch 35/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0501
# Epoch 36/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0452
# Epoch 37/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0367
# Epoch 38/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0336
# Epoch 39/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0275
# Epoch 40/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0213
# Epoch 41/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0135
# Epoch 42/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0083
# Epoch 43/500
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0060
# Epoch 44/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9996
# Epoch 45/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9919
# Epoch 46/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9871
# Epoch 47/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9832
# Epoch 48/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9775
# Epoch 49/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9714
# Epoch 50/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9664
# Epoch 51/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9627
# Epoch 52/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9586
# Epoch 53/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9537
# Epoch 54/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9469
# Epoch 55/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9431
# Epoch 56/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9383
# Epoch 57/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9334
# Epoch 58/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9270
# Epoch 59/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9235
# Epoch 60/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9191
# Epoch 61/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9142
# Epoch 62/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9083
# Epoch 63/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9030
# Epoch 64/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8988
# Epoch 65/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8955
# Epoch 66/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8899
# Epoch 67/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8862
# Epoch 68/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8806
# Epoch 69/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8773
# Epoch 70/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8727
# Epoch 71/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8682
# Epoch 72/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8623
# Epoch 73/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8590
# Epoch 74/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8542
# Epoch 75/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8489
# Epoch 76/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8467
# Epoch 77/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8407
# Epoch 78/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8350
# Epoch 79/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8328
# Epoch 80/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8281
# Epoch 81/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8230
# Epoch 82/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8183
# Epoch 83/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8130
# Epoch 84/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8096
# Epoch 85/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8050
# Epoch 86/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8003
# Epoch 87/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7946
# Epoch 88/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7893
# Epoch 89/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7852
# Epoch 90/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7816
# Epoch 91/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7760
# Epoch 92/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7729
# Epoch 93/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7682
# Epoch 94/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7642
# Epoch 95/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7592
# Epoch 96/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7526
# Epoch 97/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7501
# Epoch 98/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7433
# Epoch 99/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7388
# Epoch 100/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7343
# Epoch 101/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7318
# Epoch 102/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7266
# Epoch 103/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7204
# Epoch 104/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7146
# Epoch 105/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7124
# Epoch 106/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7052
# Epoch 107/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7004
# Epoch 108/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6968
# Epoch 109/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6919
# Epoch 110/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6865
# Epoch 111/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6831
# Epoch 112/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6754
# Epoch 113/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6730
# Epoch 114/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6655
# Epoch 115/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6607
# Epoch 116/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6555
# Epoch 117/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6509
# Epoch 118/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6481
# Epoch 119/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6423
# Epoch 120/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6356
# Epoch 121/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6292
# Epoch 122/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6254
# Epoch 123/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6205
# Epoch 124/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6140
# Epoch 125/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6097
# Epoch 126/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6043
# Epoch 127/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6002
# Epoch 128/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5936
# Epoch 129/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5884
# Epoch 130/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5816
# Epoch 131/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5782
# Epoch 132/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5712
# Epoch 133/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5673
# Epoch 134/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5630
# Epoch 135/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5559
# Epoch 136/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5517
# Epoch 137/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5464
# Epoch 138/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5381
# Epoch 139/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5354
# Epoch 140/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5286
# Epoch 141/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5220
# Epoch 142/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5196
# Epoch 143/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5134
# Epoch 144/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5052
# Epoch 145/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5022
# Epoch 146/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4952
# Epoch 147/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4915
# Epoch 148/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4828
# Epoch 149/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4779
# Epoch 150/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4740
# Epoch 151/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4691
# Epoch 152/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4608
# Epoch 153/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4567
# Epoch 154/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4502
# Epoch 155/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4471
# Epoch 156/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4410
# Epoch 157/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4352
# Epoch 158/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4284
# Epoch 159/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4231
# Epoch 160/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4187
# Epoch 161/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4118
# Epoch 162/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4052
# Epoch 163/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3998
# Epoch 164/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3962
# Epoch 165/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3902
# Epoch 166/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3862
# Epoch 167/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3806
# Epoch 168/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3734
# Epoch 169/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3672
# Epoch 170/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3643
# Epoch 171/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3566
# Epoch 172/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3514
# Epoch 173/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3491
# Epoch 174/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3419
# Epoch 175/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3377
# Epoch 176/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3307
# Epoch 177/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3257
# Epoch 178/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3223
# Epoch 179/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3142
# Epoch 180/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3107
# Epoch 181/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3066
# Epoch 182/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3005
# Epoch 183/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2943
# Epoch 184/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2919
# Epoch 185/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2841
# Epoch 186/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2824
# Epoch 187/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2756
# Epoch 188/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2697
# Epoch 189/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2672
# Epoch 190/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2615
# Epoch 191/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2565
# Epoch 192/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2511
# Epoch 193/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2477
# Epoch 194/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2446
# Epoch 195/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2398
# Epoch 196/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2351
# Epoch 197/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2301
# Epoch 198/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2250
# Epoch 199/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2199
# Epoch 200/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2160
# Epoch 201/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2139
# Epoch 202/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2075
# Epoch 203/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2060
# Epoch 204/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2004
# Epoch 205/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1965
# Epoch 206/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1915
# Epoch 207/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1901
# Epoch 208/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1847
# Epoch 209/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1817
# Epoch 210/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1762
# Epoch 211/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1729
# Epoch 212/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1703
# Epoch 213/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1677
# Epoch 214/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1634
# Epoch 215/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1583
# Epoch 216/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1561
# Epoch 217/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1517
# Epoch 218/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1487
# Epoch 219/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1455
# Epoch 220/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1430
# Epoch 221/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1391
# Epoch 222/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1361
# Epoch 223/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1338
# Epoch 224/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1306
# Epoch 225/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1283
# Epoch 226/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1252
# Epoch 227/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1206
# Epoch 228/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1196
# Epoch 229/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1152
# Epoch 230/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1127
# Epoch 231/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1116
# Epoch 232/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1074
# Epoch 233/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1055
# Epoch 234/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1025
# Epoch 235/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1001
# Epoch 236/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0984
# Epoch 237/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0961
# Epoch 238/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0943
# Epoch 239/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0917
# Epoch 240/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0884
# Epoch 241/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0871
# Epoch 242/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0854
# Epoch 243/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0826
# Epoch 244/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0803
# Epoch 245/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0790
# Epoch 246/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0777
# Epoch 247/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0746
# Epoch 248/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0729
# Epoch 249/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0716
# Epoch 250/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0700
# Epoch 251/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0688
# Epoch 252/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0669
# Epoch 253/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0644
# Epoch 254/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0633
# Epoch 255/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0623
# Epoch 256/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0599
# Epoch 257/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0590
# Epoch 258/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0572
# Epoch 259/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0563
# Epoch 260/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0547
# Epoch 261/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0542
# Epoch 262/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0524
# Epoch 263/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0509
# Epoch 264/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0497
# Epoch 265/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0490
# Epoch 266/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0475
# Epoch 267/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0467
# Epoch 268/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0460
# Epoch 269/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0443
# Epoch 270/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0440
# Epoch 271/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 272/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0414
# Epoch 273/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0408
# Epoch 274/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0397
# Epoch 275/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0389
# Epoch 276/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0381
# Epoch 277/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0374
# Epoch 278/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0371
# Epoch 279/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0358
# Epoch 280/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0353
# Epoch 281/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0344
# Epoch 282/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0339
# Epoch 283/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0330
# Epoch 284/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0328
# Epoch 285/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0318
# Epoch 286/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0316
# Epoch 287/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0310
# Epoch 288/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0302
# Epoch 289/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0297
# Epoch 290/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0293
# Epoch 291/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0287
# Epoch 292/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0281
# Epoch 293/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0276
# Epoch 294/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0275
# Epoch 295/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0268
# Epoch 296/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0264
# Epoch 297/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0260
# Epoch 298/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0257
# Epoch 299/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0254
# Epoch 300/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0247
# Epoch 301/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0244
# Epoch 302/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0240
# Epoch 303/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0238
# Epoch 304/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0233
# Epoch 305/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0230
# Epoch 306/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0227
# Epoch 307/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0223
# Epoch 308/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0222
# Epoch 309/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0217
# Epoch 310/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0215
# Epoch 311/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0213
# Epoch 312/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0210
# Epoch 313/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0207
# Epoch 314/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0203
# Epoch 315/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0202
# Epoch 316/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0198
# Epoch 317/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0196
# Epoch 318/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0194
# Epoch 319/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0192
# Epoch 320/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0190
# Epoch 321/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0187
# Epoch 322/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0185
# Epoch 323/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0183
# Epoch 324/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0182
# Epoch 325/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0180
# Epoch 326/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0177
# Epoch 327/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 328/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0174
# Epoch 329/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0172
# Epoch 330/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0171
# Epoch 331/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0169
# Epoch 332/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0167
# Epoch 333/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0166
# Epoch 334/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0165
# Epoch 335/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0163
# Epoch 336/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0162
# Epoch 337/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0161
# Epoch 338/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0160
# Epoch 339/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0158
# Epoch 340/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0158
# Epoch 341/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0156
# Epoch 342/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0155
# Epoch 343/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0154
# Epoch 344/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0153
# Epoch 345/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0152
# Epoch 346/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0151
# Epoch 347/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0150
# Epoch 348/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0149
# Epoch 349/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0149
# Epoch 350/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0148
# Epoch 351/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0147
# Epoch 352/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0146
# Epoch 353/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0145
# Epoch 354/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 355/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0144
# Epoch 356/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0143
# Epoch 357/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0143
# Epoch 358/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0142
# Epoch 359/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0141
# Epoch 360/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0140
# Epoch 361/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0139
# Epoch 362/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0138
# Epoch 363/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0135
# Epoch 364/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0134
# Epoch 365/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0130
# Epoch 366/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0128
# Epoch 367/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0125
# Epoch 368/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0123
# Epoch 369/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0121
# Epoch 370/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0118
# Epoch 371/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0117
# Epoch 372/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0114
# Epoch 373/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0112
# Epoch 374/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0110
# Epoch 375/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0108
# Epoch 376/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0107
# Epoch 377/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0105
# Epoch 378/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0103
# Epoch 379/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 380/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0101
# Epoch 381/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0099
# Epoch 382/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0098
# Epoch 383/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0097
# Epoch 384/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0095
# Epoch 385/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 386/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0093
# Epoch 387/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 388/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0091
# Epoch 389/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 390/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0089
# Epoch 391/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0088
# Epoch 392/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0087
# Epoch 393/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0086
# Epoch 394/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0085
# Epoch 395/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0084
# Epoch 396/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0084
# Epoch 397/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0083
# Epoch 398/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0083
# Epoch 399/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0083
# Epoch 400/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 401/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 402/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0082
# Epoch 403/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 404/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 405/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 406/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 407/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 408/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 409/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 410/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 411/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 412/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 413/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 414/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 415/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 416/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 417/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 418/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 419/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 420/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 421/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 422/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 423/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0078
# Epoch 424/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 425/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 426/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 427/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0078
# Epoch 428/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 429/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 430/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 431/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0077
# Epoch 432/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 433/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 434/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 435/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 436/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 437/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 438/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 439/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 440/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 441/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 442/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 443/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 444/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0076
# Epoch 445/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 446/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 447/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0076
# Epoch 448/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 449/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 450/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 451/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 452/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 453/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 454/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 455/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 456/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 457/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 458/500
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0075
# Epoch 459/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 460/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 461/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 462/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 463/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 464/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0074
# Epoch 465/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 466/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 467/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0074
# Epoch 468/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 469/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 470/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 471/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 472/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 473/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 474/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 475/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0074
# Epoch 476/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 477/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 478/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 479/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 480/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0073
# Epoch 481/500
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0073
# Epoch 482/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 483/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 484/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 485/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 486/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 487/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 488/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 489/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 490/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 491/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 492/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 493/500
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0072
# Epoch 494/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 495/500
# 3/3 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 496/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 497/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 498/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 499/500
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0072
# Epoch 500/500
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0072
# Erro no final: 0.0071868267841637135

# %% [markdown]
# ### Testando o modelo após o treinamento
# * A validação da função que a rede neural aprendeu é realizada com os dados de teste que não faziam parte do conjunto de dados de treinamento.

# %%
# Ser humano, Homo sapiens
animal = "ser humano"
mass = 6.50E+01

# Normalisação de dados de entrada
mass_normalisee = normalizador_atributo_preditiv.transform(np.array([mass]).reshape(-1, 1))
verdadeiro_valor_metabolism = 7.56E+03

# Aplicação do modelo na inferência ou predição da variável dependente e "desnormalização" do resultado
predit_metabolism = normalizador_atributo_target.inverse_transform(modelo_rede_neural.predict(mass_normalisee))[0][0]

# Exibição da previsão, valor verdadeiro (medido) e desvio (ou erro) em %
print("\nAnimal:", animal,
      ", Massa:", mass,
      ", previsão do métabolismo:", round(predit_metabolism,2),
      ", Verdadeiro valor do métabolismo:", verdadeiro_valor_metabolism,
      ",% de variância:", round((verdadeiro_valor_metabolism-predit_metabolism)/verdadeiro_valor_metabolism*100,2),"%")
# Out:
# 1/1 [==============================] - 0s 105ms/step
#
# Animal: ser humano , Massa: 65.0 , previsão do métabolismo: 8333.68 , Verdadeiro valor do métabolismo: 7560.0 ,% de variância: -10.23 %

# %%
# Gato, Felis silvestris, 3.00E+00, 5.46E+02, 11
animal = "gato"
mass = 3.00E+00

# Normalisação de dados de entrada
mass_normalisee = normalizador_atributo_preditiv.transform(np.array([mass]).reshape(-1, 1))
verdadeiro_valor_metabolism = 5.46E+02

# Aplicação do modelo na inferência ou predição da variável dependente e "desnormalização" do resultado
predit_metabolism = normalizador_atributo_target.inverse_transform(modelo_rede_neural.predict(mass_normalisee))[0][0]

# Exibição da previsão, valor verdadeiro (medido) e desvio (ou erro) em %
print("\nAnimal:", animal,
      ", Massa:", mass,
      ", previsão do métabolismo:", round(predit_metabolism,2),
      ", Verdadeiro valor do métabolismo:", verdadeiro_valor_metabolism,
      ",% de variância:", round((verdadeiro_valor_metabolism-predit_metabolism)/verdadeiro_valor_metabolism*100,2),"%")
# Out:
# 1/1 [==============================] - 0s 46ms/step
#
# Animal: gato , Massa: 3.0 , previsão do métabolismo: 507.45 , Verdadeiro valor do métabolismo: 546.0 ,% de variância: 7.06 %

# %%
# Cavalo, Equus cabalus, 4.00E+02, 3.20E+04, 40
animal = "cavalo"
mass = 4.00E+02

# Normalisação de dados de entrada
mass_normalisee = normalizador_atributo_preditiv.transform(np.array([mass]).reshape(-1, 1))
verdadeiro_valor_metabolism  = 3.20E+04

# Aplicação do modelo na inferência ou predição da variável dependente e "desnormalização" do resultado
predit_metabolisme = normalizador_atributo_target.inverse_transform(modelo_rede_neural.predict(mass_normalisee))[0][0]

# Exibição da previsão, valor verdadeiro (medido) e desvio (ou erro) em %
print("\nAnimal:", animal,
      ", Massa:", mass,
      ", previsão do métabolismo:", round(predit_metabolisme,2),
      ", Verdadeiro valor do métabolismo:", verdadeiro_valor_metabolism,
      ",% de variância:", round((verdadeiro_valor_metabolism-predit_metabolisme)/verdadeiro_valor_metabolism*100,2),"%")
# Out:
# 1/1 [==============================] - 0s 112ms/step
#
# Animal: cavalo , Massa: 400.0 , previsão do métabolismo: 31611.03 , Verdadeiro valor do métabolismo: 32000.0 ,% de variância: 1.22 %

# %% [markdown]
# ### Conclusão
#
# Observa-se que a rede neural retorna valores muito próximos dos valores verdadeiros dados pela lei de Kleiber. É importante entender que a rede neural não aprende uma fórmula exata, mas que ela se aproxima iterativamente de uma função.
#
# **NOTA**: A rede neural é capaz de aprender a aproximar uma função diretamente dos dados. O processo de aprendizagem é iterativo.

# %%
print("Projeto concluído")
# Out:
# Projeto concluído
